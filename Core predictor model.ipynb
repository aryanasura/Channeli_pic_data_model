# %%
import pandas as pd
import numpy as np

# %%
intern_file_names=pd.read_fwf("intern_file_names.txt", sep="", header=None, on_bad_lines='skip')
intern_file_names
# Out:
#           0        1    2                                                 3
# 0    Intern  results  for           M.Tech. Packaging Technology(2021-2022)
# 1    Intern  results  for                 Mechanical Engineering(2016-2017)
# 2    Intern  results  for                   Chemical Engineering(2016-2017)
# 3    Intern  results  for                 Electrical Engineering(2016-2017)
# 4    Intern  results  for  Production and Industrial Engineering(2016-2017)
# ..      ...      ...  ...                                               ...
# 563  Intern  results  for           M.Tech. CAD,CAM and Robotics(2021-2022)
# 564  Intern  results  for     M.Tech. Machine Design Engineering(2021-2022)
# 565  Intern  results  for                  M.Sc. Applied Geology(2021-2022)
# 566  Intern  results  for     M.Tech. Pulp and Paper Engineering(2021-2022)
# 567  Intern  results  for           M.Tech. Packaging Technology(2021-2022)
#
# [568 rows x 4 columns]

# %%
intern_fn=[]
with open("intern_file_names.txt",'r') as f:
    for line in f:
        intern_fn.append(line[0:-1])
intern_fn
# Out:
# ['Intern results for M.Tech. Packaging Technology(2021-2022)',
#  'Intern results for Mechanical Engineering(2016-2017)',
#  'Intern results for Chemical Engineering(2016-2017)',
#  'Intern results for Electrical Engineering(2016-2017)',
#  'Intern results for Production and Industrial Engineering(2016-2017)',
#  'Intern results for Electronics & Communication Engineering(2016-2017)',
#  'Intern results for Computer Science and Engineering(2016-2017)',
#  'Intern results for Metallurgical & Materials Engineering(2016-2017)',
#  'Intern results for Geophysical Technology(2016-2017)',
#  'Intern results for Civil Engineering(2016-2017)',
#  'Intern results for Geological Technology(2016-2017)',
#  'Intern results for Biotechnology(2016-2017)',
#  'Intern results for Applied Mathematics(2016-2017)',
#  'Intern results for Computer Science & Engineering(2016-2017)',
#  'Intern results for Architecture and Planning(2016-2017)',
# ...

# %%
placement_fn=[]
with open("placement_file_names.txt",'r') as g:
    for line in g:
        placement_fn.append(line[0:-1])
placement_fn
# Out:
# ['Placement results for Applied Mathematics(2016-2017)',
#  'Placement results for B. Tech. (Chemical Engineering) and M. Tech. (Hydrocarbon Engineering)(2016-2017)',
#  'Placement results for B. Tech. (Electrical Engineering) and M.Tech. (Power Electronics)(2016-2017)',
#  'Placement results for Civil Engineering(2016-2017)',
#  'Placement results for Biotechnology(2016-2017)',
#  'Placement results for Management and Business Administration(2016-2017)',
#  'Placement results for B. Tech. (Process Engineering) and M.B.A.(2016-2017)',
#  'Placement results for Architecture and Planning(2016-2017)',
#  'Placement results for Micro Electronic and VLSI(2016-2017)',
#  'Placement results for B. Tech. (Computer Science & Engineering) and M. Tech. (Information Technology)(2016-2017)',
#  'Placement results for Structural Dynamics(2016-2017)',
#  'Placement results for Transportation Engineering(2016-2017)',
# ...
